# %% [markdown]
# <a href="https://colab.research.google.com/github/purnendux95/Space-cadet/blob/main/M3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#PANDAS - Python library, which is used to create DATAFRAME and series
##dataframe - tabled data(data in form of table)
#series - column

# %%
mydataset = {'cars':['BMW','Volvo','Ford'],'passings':[3,7,2]}
mydataset
type(mydataset)
# Out:
# dict

# %%
import pandas as pd
df=pd.DataFrame(mydataset)
df
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
a=[1,7,2,6]
myvar=pd.Series(a)
myvar
# Out:
# 0    1
# 1    7
# 2    2
# 3    6
# dtype: int64

# %%
#using pandas we can easily change the index
a=[1,7,2,6]
myvar1=pd.Series(a,index=['w','x','y','z'])
myvar1
# Out:
# w    1
# x    7
# y    2
# z    6
# dtype: int64

# %%
sports1=pd.Series([1,2,3,4],index=['Cricket','Football','hockey','Golf'])
sports1
# Out:
# Cricket     1
# Football    2
# hockey      3
# Golf        4
# dtype: int64

# %%
sports2=pd.Series([1,2,5,4],index=['Cricket','basketball','baseball','golf'])
sports2
# Out:
# Cricket       1
# basketball    2
# baseball      5
# golf          4
# dtype: int64

# %%
s=sports1+sports2
s
# Out:
# Cricket       2.0
# Football      NaN
# Golf          NaN
# baseball      NaN
# basketball    NaN
# golf          NaN
# hockey        NaN
# dtype: float64

# %%
#nan - Not a number(null value/missing values)
#whenever nan comes into picture, int is vonvertedd to float

# %%
s.dropna()#let us drop all the null values
# Out:
# Cricket    2.0
# dtype: float64

# %%
#now let us replace the nan values with a number
s.fillna(value=1)
# Out:
# Cricket       2.0
# Football      1.0
# Golf          1.0
# baseball      1.0
# basketball    1.0
# golf          1.0
# hockey        1.0
# dtype: float64

# %%
s
# Out:
# Cricket       2.0
# Football      NaN
# Golf          NaN
# baseball      NaN
# basketball    NaN
# golf          NaN
# hockey        NaN
# dtype: float64

# %%
#Exploratory Data Analysis - EDA(PRE MACHINE LEARNING)
#EDA - WE FIND DIFFERENT INSIGHTS, WE COME TO DIFFERENT CONCLUSION AND EXPLORE OUR DATA)

# %%
#DATAFRAME - Tabled data
#dataset - is raw unprocessed data in form of rows ADN COLUMNS

# %%
#Dataset -  https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20221129%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20221129T150058Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
#1.Take the Data and create DataFrame
# import pandas as pd
# df = pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20221129%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20221129T150058Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...',sep = '\t')
# df

# %%
import pandas as pd
df = pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230105%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230105T151859Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...',sep = '\t')
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/fruit_data_with_colors.txt',sep = '\t')
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
df.shape #59rows, 7 rows
# Out:
# (59, 7)

# %%
df.size #Total number of elements in dataframe
# Out:
# 413

# %%
df.info() #it gives info about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_label    59 non-null     int64
#  1   fruit_name     59 non-null     object
#  2   fruit_subtype  59 non-null     object
#  3   mass           59 non-null     int64
#  4   width          59 non-null     float64
#  5   height         59 non-null     float64
#  6   color_score    59 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 3.4+ KB

# %%
#slicing 
#slice row indexes from 25 to 43
#var[inclusive:exclusive
df[25:44] #25 is inclusive and 44 is exclusive
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 25            3     orange     spanish_jumbo   356    9.2     9.2         0.75
# 26            3     orange     spanish_jumbo   362    9.6     9.2         0.74
# 27            3     orange  selected_seconds   204    7.5     9.2         0.77
# 28            3     orange  selected_seconds   140    6.7     7.1         0.72
# 29            3     orange  selected_seconds   160    7.0     7.4         0.81
# 30            3     orange  selected_seconds   158    7.1     7.5         0.79
# 31            3     orange  selected_seconds   210    7.8     8.0         0.82
# 32            3     orange  selected_seconds   164    7.2     7.0         0.80
# 33            3     orange      turkey_navel   190    7.5     8.1         0.74
# 34            3     orange      turkey_navel   142    7.6     7.8         0.75
# 35            3     orange      turkey_navel   150    7.1     7.9         0.75
# ...

# %%
#slicing 
#slice row indexes from 25 to 43 and column indexes 0 to 1.
#var.iloc[row slicing column slicing]
df.iloc[25:40,0:2]
# Out:
#     fruit_label fruit_name
# 25            3     orange
# 26            3     orange
# 27            3     orange
# 28            3     orange
# 29            3     orange
# 30            3     orange
# 31            3     orange
# 32            3     orange
# 33            3     orange
# 34            3     orange
# 35            3     orange
# 36            3     orange
# 37            3     orange
# 38            3     orange
# 39            3     orange

# %%
#now i just want to know the no. of unique fruits names
df.fruit_name.nunique()
# Out:
# 4

# %%
df['fruit_name'].nunique()
# Out:
# 4

# %%
#I want the unique fruit names 
df.fruit_name.unique()
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
df['fruit_name'].unique()
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
fname=df.fruit_name.unique()

# %%
fname
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
#now i want the exact count of each and every fruit 
#Apples - 19
#Mandarin-5
#orange - 19
#lemons - 16

# %%
fsize = df.groupby('fruit_name').size()
fsize
#here .group by sorts out fruit names in alphabetical order
# Out:
# fruit_name
# apple       19
# lemon       16
# mandarin     5
# orange      19
# dtype: int64

# %%
#Visualization
import matplotlib.pyplot as plt
plt.bar(fname,fsize,color =['red','gold','orange','lime'] )
# Out:
# <BarContainer object of 4 artists>
